# %%
import pandas as pd

# %%
#read all metadata
metadata_file = "GSE25070_metadata_all.csv" 
metadata = pd.read_csv(metadata_file)

# %%
metadata.describe()
# Out:
#                                    title geo_accession  \
# count                                 52            52
# unique                                52            52
# top     "Colorectal Adenocarinoma 17753"   "GSM615865"
# freq                                   1             1
#
#                          status submission_date last_update_date   type  \
# count                        52              52               52     52
# unique                        1               1                1      1
# top     "Public on Jun 03 2011"   "Nov 01 2010"    "Jun 03 2011"  "RNA"
# freq                         52              52               52     52
#
#        channel_count                                   source_name_ch1  \
# count             52                                                52
# unique             1                                                52
# top              "1"  "total RNA from colorectal adenocarcinoma 17753"
# freq              52                                                 1
#
#           organism_ch1 characteristics_ch1  ...      contact_email  \
# count               52                  52  ...                 52
# unique               1                  27  ...                  1
# top     "Homo sapiens"                  ""  ...  "thinoue@usc.edu"
# freq                52                  26  ...                 52
#
#          contact_phone       contact_institute                contact_address  \
# count               52                      52                             52
# unique               1                       1                              1
# top     "323-442-7458"  "USC Epigenome Center"  "1450 Biggy Street, NRT G511"
# freq                52                      52                             52
#
#          contact_city contact_state contact_zip/postal_code contact_country  \
# count              52            52                      52              52
# unique              1             1                       1               1
# top     "Los Angeles"          "CA"            "90033-9601"           "USA"
# freq               52            52                      52              52
#
#                                        supplementary_file data_row_count
# count                                                  52             52
# unique                                                 52              1
# top     "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM615...        "24526"
# freq                                                    1             52
#
# [4 rows x 31 columns]

# %%
metadata.head()
# Out:
#                               title geo_accession                   status  \
# 0  "Colorectal Adenocarinoma 17753"   "GSM615865"  "Public on Jun 03 2011"
# 1  "Colorectal Adenocarinoma 17754"   "GSM615866"  "Public on Jun 03 2011"
# 2  "Colorectal Adenocarinoma 17755"   "GSM615867"  "Public on Jun 03 2011"
# 3  "Colorectal Adenocarinoma 17756"   "GSM615868"  "Public on Jun 03 2011"
# 4  "Colorectal Adenocarinoma 17757"   "GSM615869"  "Public on Jun 03 2011"
#
#   submission_date last_update_date   type channel_count  \
# 0   "Nov 01 2010"    "Jun 03 2011"  "RNA"           "1"
# 1   "Nov 01 2010"    "Jun 03 2011"  "RNA"           "1"
# 2   "Nov 01 2010"    "Jun 03 2011"  "RNA"           "1"
# 3   "Nov 01 2010"    "Jun 03 2011"  "RNA"           "1"
# 4   "Nov 01 2010"    "Jun 03 2011"  "RNA"           "1"
#
#                                     source_name_ch1    organism_ch1  \
# 0  "total RNA from colorectal adenocarcinoma 17753"  "Homo sapiens"
# 1  "total RNA from colorectal adenocarcinoma 17754"  "Homo sapiens"
# 2  "total RNA from colorectal adenocarcinoma 17755"  "Homo sapiens"
# 3  "total RNA from colorectal adenocarcinoma 17756"  "Homo sapiens"
# 4  "total RNA from colorectal adenocarcinoma 17757"  "Homo sapiens"
#
#                            characteristics_ch1  ...      contact_email  \
# 0  "tissue pair: normal adjacent tissue 17779"  ...  "thinoue@usc.edu"
# 1  "tissue pair: normal adjacent tissue 17780"  ...  "thinoue@usc.edu"
# 2  "tissue pair: normal adjacent tissue 17781"  ...  "thinoue@usc.edu"
# 3  "tissue pair: normal adjacent tissue 17782"  ...  "thinoue@usc.edu"
# 4  "tissue pair: normal adjacent tissue 17783"  ...  "thinoue@usc.edu"
#
#     contact_phone       contact_institute                contact_address  \
# 0  "323-442-7458"  "USC Epigenome Center"  "1450 Biggy Street, NRT G511"
# 1  "323-442-7458"  "USC Epigenome Center"  "1450 Biggy Street, NRT G511"
# 2  "323-442-7458"  "USC Epigenome Center"  "1450 Biggy Street, NRT G511"
# 3  "323-442-7458"  "USC Epigenome Center"  "1450 Biggy Street, NRT G511"
# 4  "323-442-7458"  "USC Epigenome Center"  "1450 Biggy Street, NRT G511"
#
#     contact_city contact_state contact_zip/postal_code contact_country  \
# 0  "Los Angeles"          "CA"            "90033-9601"           "USA"
# 1  "Los Angeles"          "CA"            "90033-9601"           "USA"
# 2  "Los Angeles"          "CA"            "90033-9601"           "USA"
# 3  "Los Angeles"          "CA"            "90033-9601"           "USA"
# 4  "Los Angeles"          "CA"            "90033-9601"           "USA"
#
#                                   supplementary_file data_row_count
# 0  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM615...        "24526"
# 1  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM615...        "24526"
# 2  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM615...        "24526"
# 3  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM615...        "24526"
# 4  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM615...        "24526"
#
# [5 rows x 31 columns]

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    52 non-null     object
#  1   geo_accession            52 non-null     object
#  2   status                   52 non-null     object
#  3   submission_date          52 non-null     object
#  4   last_update_date         52 non-null     object
#  5   type                     52 non-null     object
#  6   channel_count            52 non-null     object
#  7   source_name_ch1          52 non-null     object
#  8   organism_ch1             52 non-null     object
#  9   characteristics_ch1      52 non-null     object
#  10  molecule_ch1             52 non-null     object
#  11  extract_protocol_ch1     52 non-null     object
#  12  label_ch1                52 non-null     object
#  13  label_protocol_ch1       52 non-null     object
#  14  taxid_ch1                52 non-null     object
#  15  hyb_protocol             52 non-null     object
#  16  scan_protocol            52 non-null     object
#  17  description              52 non-null     object
#  18  data_processing          52 non-null     object
#  19  platform_id              52 non-null     object
#  20  contact_name             52 non-null     object
#  21  contact_email            52 non-null     object
#  22  contact_phone            52 non-null     object
#  23  contact_institute        52 non-null     object
#  24  contact_address          52 non-null     object
#  25  contact_city             52 non-null     object
#  26  contact_state            52 non-null     object
#  27  contact_zip/postal_code  52 non-null     object
#  28  contact_country          52 non-null     object
#  29  supplementary_file       52 non-null     object
#  30  data_row_count           52 non-null     object
# dtypes: object(31)
# memory usage: 12.7+ KB

# %%
metadata.shape
# Out:
# (52, 31)

# %%
metadata.columns
# Out:
# Index(['title', 'geo_accession', 'status', 'submission_date',
#        'last_update_date', 'type', 'channel_count', 'source_name_ch1',
#        'organism_ch1', 'characteristics_ch1', 'molecule_ch1',
#        'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1', 'taxid_ch1',
#        'hyb_protocol', 'scan_protocol', 'description', 'data_processing',
#        'platform_id', 'contact_name', 'contact_email', 'contact_phone',
#        'contact_institute', 'contact_address', 'contact_city', 'contact_state',
#        'contact_zip/postal_code', 'contact_country', 'supplementary_file',
#        'data_row_count'],
#       dtype='object')

# %%
# List of columns to remove
columns_to_remove = [
    "status", "submission_date", "last_update_date", "type", "channel_count",
    "source_name_ch1", "organism_ch1", "characteristics_ch1",'molecule_ch1',
       'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1', 'taxid_ch1',
       'hyb_protocol', 'scan_protocol', 'description', 'data_processing', "platform_id",
    "contact_name", "contact_email",'contact_phone', "contact_institute", "contact_address",
    "contact_city", 'contact_state', "contact_zip/postal_code", "contact_country",
    "supplementary_file", "data_row_count"
]

metadata_cleaned = metadata.drop(columns=columns_to_remove, errors="ignore")

# %%
metadata_cleaned.head()
# Out:
#                               title geo_accession
# 0  "Colorectal Adenocarinoma 17753"   "GSM615865"
# 1  "Colorectal Adenocarinoma 17754"   "GSM615866"
# 2  "Colorectal Adenocarinoma 17755"   "GSM615867"
# 3  "Colorectal Adenocarinoma 17756"   "GSM615868"
# 4  "Colorectal Adenocarinoma 17757"   "GSM615869"

# %%
metadata_cleaned.tail()
# Out:
#                                            title geo_accession
# 47  "Adjacent non-tumor colorectal tissue 17800"   "GSM615912"
# 48  "Adjacent non-tumor colorectal tissue 17801"   "GSM615913"
# 49  "Adjacent non-tumor colorectal tissue 17802"   "GSM615914"
# 50  "Adjacent non-tumor colorectal tissue 17803"   "GSM615915"
# 51  "Adjacent non-tumor colorectal tissue 17804"   "GSM615916"

# %%
metadata_cleaned["target"] = metadata_cleaned["title"].str.extract(r"(Colorectal Adenocarinoma|non-tumor)")

# %%
metadata_cleaned.head()
# Out:
#                               title geo_accession                    target
# 0  "Colorectal Adenocarinoma 17753"   "GSM615865"  Colorectal Adenocarinoma
# 1  "Colorectal Adenocarinoma 17754"   "GSM615866"  Colorectal Adenocarinoma
# 2  "Colorectal Adenocarinoma 17755"   "GSM615867"  Colorectal Adenocarinoma
# 3  "Colorectal Adenocarinoma 17756"   "GSM615868"  Colorectal Adenocarinoma
# 4  "Colorectal Adenocarinoma 17757"   "GSM615869"  Colorectal Adenocarinoma

# %%
metadata_cleaned.tail()
# Out:
#                                            title geo_accession     target
# 47  "Adjacent non-tumor colorectal tissue 17800"   "GSM615912"  non-tumor
# 48  "Adjacent non-tumor colorectal tissue 17801"   "GSM615913"  non-tumor
# 49  "Adjacent non-tumor colorectal tissue 17802"   "GSM615914"  non-tumor
# 50  "Adjacent non-tumor colorectal tissue 17803"   "GSM615915"  non-tumor
# 51  "Adjacent non-tumor colorectal tissue 17804"   "GSM615916"  non-tumor

# %%
metadata_cleaned
# Out:
#                                            title geo_accession  \
# 0               "Colorectal Adenocarinoma 17753"   "GSM615865"
# 1               "Colorectal Adenocarinoma 17754"   "GSM615866"
# 2               "Colorectal Adenocarinoma 17755"   "GSM615867"
# 3               "Colorectal Adenocarinoma 17756"   "GSM615868"
# 4               "Colorectal Adenocarinoma 17757"   "GSM615869"
# 5               "Colorectal Adenocarinoma 17758"   "GSM615870"
# 6               "Colorectal Adenocarinoma 17759"   "GSM615871"
# 7               "Colorectal Adenocarinoma 17760"   "GSM615872"
# 8               "Colorectal Adenocarinoma 17761"   "GSM615873"
# 9               "Colorectal Adenocarinoma 17762"   "GSM615874"
# 10              "Colorectal Adenocarinoma 17763"   "GSM615875"
# 11              "Colorectal Adenocarinoma 17764"   "GSM615876"
# 12              "Colorectal Adenocarinoma 17765"   "GSM615877"
# 13              "Colorectal Adenocarinoma 17766"   "GSM615878"
# 14              "Colorectal Adenocarinoma 17767"   "GSM615879"
# 15              "Colorectal Adenocarinoma 17768"   "GSM615880"
# 16              "Colorectal Adenocarinoma 17769"   "GSM615881"
# 17              "Colorectal Adenocarinoma 17770"   "GSM615882"
# 18              "Colorectal Adenocarinoma 17771"   "GSM615883"
# 19              "Colorectal Adenocarinoma 17772"   "GSM615884"
# 20              "Colorectal Adenocarinoma 17773"   "GSM615885"
# 21              "Colorectal Adenocarinoma 17774"   "GSM615886"
# 22              "Colorectal Adenocarinoma 17775"   "GSM615887"
# 23              "Colorectal Adenocarinoma 17776"   "GSM615888"
# 24              "Colorectal Adenocarinoma 17777"   "GSM615889"
# 25              "Colorectal Adenocarinoma 17778"   "GSM615890"
# 26  "Adjacent non-tumor colorectal tissue 17779"   "GSM615891"
# 27  "Adjacent non-tumor colorectal tissue 17780"   "GSM615892"
# 28  "Adjacent non-tumor colorectal tissue 17781"   "GSM615893"
# 29  "Adjacent non-tumor colorectal tissue 17782"   "GSM615894"
# 30  "Adjacent non-tumor colorectal tissue 17783"   "GSM615895"
# 31  "Adjacent non-tumor colorectal tissue 17784"   "GSM615896"
# 32  "Adjacent non-tumor colorectal tissue 17785"   "GSM615897"
# 33  "Adjacent non-tumor colorectal tissue 17786"   "GSM615898"
# 34  "Adjacent non-tumor colorectal tissue 17787"   "GSM615899"
# 35  "Adjacent non-tumor colorectal tissue 17788"   "GSM615900"
# 36  "Adjacent non-tumor colorectal tissue 17789"   "GSM615901"
# 37  "Adjacent non-tumor colorectal tissue 17790"   "GSM615902"
# 38  "Adjacent non-tumor colorectal tissue 17791"   "GSM615903"
# 39  "Adjacent non-tumor colorectal tissue 17792"   "GSM615904"
# 40  "Adjacent non-tumor colorectal tissue 17793"   "GSM615905"
# 41  "Adjacent non-tumor colorectal tissue 17794"   "GSM615906"
# 42  "Adjacent non-tumor colorectal tissue 17795"   "GSM615907"
# 43  "Adjacent non-tumor colorectal tissue 17796"   "GSM615908"
# 44  "Adjacent non-tumor colorectal tissue 17797"   "GSM615909"
# 45  "Adjacent non-tumor colorectal tissue 17798"   "GSM615910"
# 46  "Adjacent non-tumor colorectal tissue 17799"   "GSM615911"
# 47  "Adjacent non-tumor colorectal tissue 17800"   "GSM615912"
# 48  "Adjacent non-tumor colorectal tissue 17801"   "GSM615913"
# 49  "Adjacent non-tumor colorectal tissue 17802"   "GSM615914"
# 50  "Adjacent non-tumor colorectal tissue 17803"   "GSM615915"
# 51  "Adjacent non-tumor colorectal tissue 17804"   "GSM615916"
#
#                       target
# 0   Colorectal Adenocarinoma
# 1   Colorectal Adenocarinoma
# 2   Colorectal Adenocarinoma
# 3   Colorectal Adenocarinoma
# 4   Colorectal Adenocarinoma
# 5   Colorectal Adenocarinoma
# 6   Colorectal Adenocarinoma
# 7   Colorectal Adenocarinoma
# 8   Colorectal Adenocarinoma
# 9   Colorectal Adenocarinoma
# 10  Colorectal Adenocarinoma
# 11  Colorectal Adenocarinoma
# 12  Colorectal Adenocarinoma
# 13  Colorectal Adenocarinoma
# 14  Colorectal Adenocarinoma
# 15  Colorectal Adenocarinoma
# 16  Colorectal Adenocarinoma
# 17  Colorectal Adenocarinoma
# 18  Colorectal Adenocarinoma
# 19  Colorectal Adenocarinoma
# 20  Colorectal Adenocarinoma
# 21  Colorectal Adenocarinoma
# 22  Colorectal Adenocarinoma
# 23  Colorectal Adenocarinoma
# 24  Colorectal Adenocarinoma
# 25  Colorectal Adenocarinoma
# 26                 non-tumor
# 27                 non-tumor
# 28                 non-tumor
# 29                 non-tumor
# 30                 non-tumor
# 31                 non-tumor
# 32                 non-tumor
# 33                 non-tumor
# 34                 non-tumor
# 35                 non-tumor
# 36                 non-tumor
# 37                 non-tumor
# 38                 non-tumor
# 39                 non-tumor
# 40                 non-tumor
# 41                 non-tumor
# 42                 non-tumor
# 43                 non-tumor
# 44                 non-tumor
# 45                 non-tumor
# 46                 non-tumor
# 47                 non-tumor
# 48                 non-tumor
# 49                 non-tumor
# 50                 non-tumor
# 51                 non-tumor

# %%
metadata_final = metadata_cleaned.drop(columns='title', errors="ignore")

# %%
metadata_final.head()
# Out:
#   geo_accession                    target
# 0   "GSM615865"  Colorectal Adenocarinoma
# 1   "GSM615866"  Colorectal Adenocarinoma
# 2   "GSM615867"  Colorectal Adenocarinoma
# 3   "GSM615868"  Colorectal Adenocarinoma
# 4   "GSM615869"  Colorectal Adenocarinoma

# %%
# Remove quotes from the geo_accession column (it's the first column)
metadata_final.iloc[:, 0] = metadata_final.iloc[:, 0].str.replace('"', '', regex=False)

# %%
metadata_cleaned= metadata_final
metadata_cleaned.head()
# Out:
#   geo_accession                    target
# 0     GSM615865  Colorectal Adenocarinoma
# 1     GSM615866  Colorectal Adenocarinoma
# 2     GSM615867  Colorectal Adenocarinoma
# 3     GSM615868  Colorectal Adenocarinoma
# 4     GSM615869  Colorectal Adenocarinoma

# %%
# Save the cleaned metadata
metadata_cleaned.to_csv("metadata_cleaned.csv", index=False)

print("Columns removed and saved as metadata_cleaned.csv")
# Out:
# Columns removed and saved as metadata_cleaned.csv
