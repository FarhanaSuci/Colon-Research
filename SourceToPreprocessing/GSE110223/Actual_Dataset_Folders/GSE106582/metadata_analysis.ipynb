# %%
import pandas as pd

# %%
#read all metadata
metadata_file = "GSE106582_metadata_all.csv"
metadata = pd.read_csv(metadata_file)

# %%
metadata.describe()
# Out:
#              title geo_accession                   status submission_date  \
# count          194           194                      194             194
# unique         194           194                        1               1
# top     "400072_A"  "GSM2843099"  "Public on Dec 01 2018"   "Nov 06 2017"
# freq             1             1                      194             194
#
#        last_update_date   type channel_count                 source_name_ch1  \
# count               194    194           194                             194
# unique                1      1             1                             194
# top       "Dec 01 2018"  "RNA"           "1"  "Patient 400072; Tissue tumor"
# freq                194    194           194                               1
#
#           organism_ch1                         characteristics_ch1  ...  \
# count              194                                         194  ...
# ...

# %%
metadata.head()
# Out:
#         title geo_accession                   status submission_date  \
# 0  "400072_A"  "GSM2843099"  "Public on Dec 01 2018"   "Nov 06 2017"
# 1  "400072_C"  "GSM2843100"  "Public on Dec 01 2018"   "Nov 06 2017"
# 2  "400152_A"  "GSM2843101"  "Public on Dec 01 2018"   "Nov 06 2017"
# 3  "400152_C"  "GSM2843102"  "Public on Dec 01 2018"   "Nov 06 2017"
# 4  "400200_C"  "GSM2843103"  "Public on Dec 01 2018"   "Nov 06 2017"
#
#   last_update_date   type channel_count                  source_name_ch1  \
# 0    "Dec 01 2018"  "RNA"           "1"   "Patient 400072; Tissue tumor"
# 1    "Dec 01 2018"  "RNA"           "1"  "Patient 400072; Tissue mucosa"
# 2    "Dec 01 2018"  "RNA"           "1"   "Patient 400152; Tissue tumor"
# 3    "Dec 01 2018"  "RNA"           "1"  "Patient 400152; Tissue mucosa"
# 4    "Dec 01 2018"  "RNA"           "1"  "Patient 400200; Tissue mucosa"
#
#      organism_ch1                         characteristics_ch1  ...  \
# ...

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    194 non-null    object
#  1   geo_accession            194 non-null    object
#  2   status                   194 non-null    object
#  3   submission_date          194 non-null    object
#  4   last_update_date         194 non-null    object
#  5   type                     194 non-null    object
#  6   channel_count            194 non-null    object
#  7   source_name_ch1          194 non-null    object
#  8   organism_ch1             194 non-null    object
#  9   characteristics_ch1      194 non-null    object
#  10  molecule_ch1             194 non-null    object
#  11  extract_protocol_ch1     194 non-null    object
#  12  label_ch1                194 non-null    object
#  13  label_protocol_ch1       194 non-null    object
# ...

# %%
metadata.shape
# Out:
# (194, 27)

# %%
metadata.columns
# Out:
# Index(['title', 'geo_accession', 'status', 'submission_date',
#        'last_update_date', 'type', 'channel_count', 'source_name_ch1',
#        'organism_ch1', 'characteristics_ch1', 'molecule_ch1',
#        'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1', 'taxid_ch1',
#        'hyb_protocol', 'scan_protocol', 'data_processing', 'platform_id',
#        'contact_name', 'contact_institute', 'contact_address', 'contact_city',
#        'contact_zip/postal_code', 'contact_country', 'supplementary_file',
#        'data_row_count'],
#       dtype='object')

# %%
# List of columns to remove
columns_to_remove = [
    "title","status", "submission_date", "last_update_date", "type", "channel_count",
     "organism_ch1", "characteristics_ch1",'molecule_ch1',
       'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1',"treatment_protocol_ch1", 'taxid_ch1',
       'hyb_protocol', 'scan_protocol', 'description', 'data_processing', "platform_id",
    "contact_name", "contact_email",'contact_phone', "contact_institute", "contact_address",
    "contact_city", 'contact_state', "contact_zip/postal_code", "contact_country","contact_department",
    "contact_fax","contact_laboratory", "supplementary_file", "data_row_count"
]

metadata_cleaned = metadata.drop(columns=columns_to_remove, errors="ignore")

# %%
metadata_cleaned.head()
# Out:
#   geo_accession                  source_name_ch1
# 0  "GSM2843099"   "Patient 400072; Tissue tumor"
# 1  "GSM2843100"  "Patient 400072; Tissue mucosa"
# 2  "GSM2843101"   "Patient 400152; Tissue tumor"
# 3  "GSM2843102"  "Patient 400152; Tissue mucosa"
# 4  "GSM2843103"  "Patient 400200; Tissue mucosa"

# %%
metadata_cleaned.tail()
# Out:
#     geo_accession                  source_name_ch1
# 189  "GSM2843288"   "Patient 404656; Tissue tumor"
# 190  "GSM2843289"  "Patient 404656; Tissue mucosa"
# 191  "GSM2843290"  "Patient 404768; Tissue mucosa"
# 192  "GSM2843291"   "Patient 404848; Tissue tumor"
# 193  "GSM2843292"  "Patient 404848; Tissue mucosa"

# %%
metadata_cleaned["target"] = metadata_cleaned["source_name_ch1"].str.extract(r"(mucosa|tumor)")

# %%
metadata_cleaned.head()
# Out:
#   geo_accession                  source_name_ch1  target
# 0  "GSM2843099"   "Patient 400072; Tissue tumor"   tumor
# 1  "GSM2843100"  "Patient 400072; Tissue mucosa"  mucosa
# 2  "GSM2843101"   "Patient 400152; Tissue tumor"   tumor
# 3  "GSM2843102"  "Patient 400152; Tissue mucosa"  mucosa
# 4  "GSM2843103"  "Patient 400200; Tissue mucosa"  mucosa

# %%
metadata_cleaned.tail()
# Out:
#     geo_accession                  source_name_ch1  target
# 189  "GSM2843288"   "Patient 404656; Tissue tumor"   tumor
# 190  "GSM2843289"  "Patient 404656; Tissue mucosa"  mucosa
# 191  "GSM2843290"  "Patient 404768; Tissue mucosa"  mucosa
# 192  "GSM2843291"   "Patient 404848; Tissue tumor"   tumor
# 193  "GSM2843292"  "Patient 404848; Tissue mucosa"  mucosa

# %%
metadata_cleaned
# Out:
#     geo_accession                  source_name_ch1  target
# 0    "GSM2843099"   "Patient 400072; Tissue tumor"   tumor
# 1    "GSM2843100"  "Patient 400072; Tissue mucosa"  mucosa
# 2    "GSM2843101"   "Patient 400152; Tissue tumor"   tumor
# 3    "GSM2843102"  "Patient 400152; Tissue mucosa"  mucosa
# 4    "GSM2843103"  "Patient 400200; Tissue mucosa"  mucosa
# ..            ...                              ...     ...
# 189  "GSM2843288"   "Patient 404656; Tissue tumor"   tumor
# 190  "GSM2843289"  "Patient 404656; Tissue mucosa"  mucosa
# 191  "GSM2843290"  "Patient 404768; Tissue mucosa"  mucosa
# 192  "GSM2843291"   "Patient 404848; Tissue tumor"   tumor
# 193  "GSM2843292"  "Patient 404848; Tissue mucosa"  mucosa
#
# [194 rows x 3 columns]

# %%
metadata_final = metadata_cleaned.drop(columns='source_name_ch1', errors="ignore")

# %%
metadata_final.head()
# Out:
#   geo_accession  target
# 0  "GSM2843099"   tumor
# 1  "GSM2843100"  mucosa
# 2  "GSM2843101"   tumor
# 3  "GSM2843102"  mucosa
# 4  "GSM2843103"  mucosa

# %%
# Remove quotes from the geo_accession column (it's the first column)
metadata_final.iloc[:, 0] = metadata_final.iloc[:, 0].str.replace('"', '', regex=False)

# %%
metadata_cleaned= metadata_final
metadata_cleaned.head()
# Out:
#   geo_accession  target
# 0    GSM2843099   tumor
# 1    GSM2843100  mucosa
# 2    GSM2843101   tumor
# 3    GSM2843102  mucosa
# 4    GSM2843103  mucosa

# %%
# Save the cleaned metadata
metadata_cleaned.to_csv("metadata_cleaned.csv", index=False)

print("Columns removed and saved as metadata_cleaned.csv")
# Out:
# Columns removed and saved as metadata_cleaned.csv
