# %%
import pandas as pd

# %%
#read all metadata
metadata_file = "GSE113513_metadata_all.csv" 
metadata = pd.read_csv(metadata_file)

# %%
metadata.describe()
# Out:
#                                        title geo_accession  \
# count                                     28            28
# unique                                    28            28
# top     "non-cancerous surrounding tissue-1"  "GSM3108231"
# freq                                       1             1
#
#                          status submission_date last_update_date   type  \
# count                        28              28               28     28
# unique                        1               1                1      1
# top     "Public on Apr 24 2018"   "Apr 23 2018"    "Apr 24 2018"  "RNA"
# freq                         28              28               28     28
#
#        channel_count                    source_name_ch1    organism_ch1  \
# count             28                                 28              28
# unique             1                                  2               1
# top              "1"  "non-cancerous colorectal tissue"  "Homo sapiens"
# freq              28                                 14              28
#
#                        characteristics_ch1  ...          contact_email  \
# count                                   28  ...                     28
# unique                                   2  ...                      1
# top     "tissue: non-cancerous colorectal"  ...  "pjunlab@hotmail.com"
# freq                                    14  ...                     28
#
#                        contact_department  \
# count                                  28
# unique                                  1
# top     "Academy of Integrative Medicine"
# freq                                   28
#
#                                         contact_institute  \
# count                                                  28
# unique                                                  1
# top     "Fujian University of Traditional Chinese Medi...
# freq                                                   28
#
#                           contact_address contact_city contact_state  \
# count                                  28           28            28
# unique                                  1            1             1
# top     "1 Qiuyang Road, Minhou Shangjie"     "Fuzhou"      "Fujian"
# freq                                   28           28            28
#
#        contact_zip/postal_code contact_country  \
# count                       28              28
# unique                       1               1
# top                   "350122"         "China"
# freq                        28              28
#
#                                        supplementary_file data_row_count
# count                                                  28             28
# unique                                                 28              1
# top     "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM310...        "49395"
# freq                                                    1             28
#
# [4 rows x 32 columns]

# %%
metadata.head()
# Out:
#                                   title geo_accession  \
# 0  "non-cancerous surrounding tissue-1"  "GSM3108231"
# 1  "non-cancerous surrounding tissue-2"  "GSM3108232"
# 2  "non-cancerous surrounding tissue-3"  "GSM3108233"
# 3  "non-cancerous surrounding tissue-4"  "GSM3108234"
# 4  "non-cancerous surrounding tissue-5"  "GSM3108235"
#
#                     status submission_date last_update_date   type  \
# 0  "Public on Apr 24 2018"   "Apr 23 2018"    "Apr 24 2018"  "RNA"
# 1  "Public on Apr 24 2018"   "Apr 23 2018"    "Apr 24 2018"  "RNA"
# 2  "Public on Apr 24 2018"   "Apr 23 2018"    "Apr 24 2018"  "RNA"
# 3  "Public on Apr 24 2018"   "Apr 23 2018"    "Apr 24 2018"  "RNA"
# 4  "Public on Apr 24 2018"   "Apr 23 2018"    "Apr 24 2018"  "RNA"
#
#   channel_count                    source_name_ch1    organism_ch1  \
# 0           "1"  "non-cancerous colorectal tissue"  "Homo sapiens"
# 1           "1"  "non-cancerous colorectal tissue"  "Homo sapiens"
# 2           "1"  "non-cancerous colorectal tissue"  "Homo sapiens"
# 3           "1"  "non-cancerous colorectal tissue"  "Homo sapiens"
# 4           "1"  "non-cancerous colorectal tissue"  "Homo sapiens"
#
#                   characteristics_ch1  ...          contact_email  \
# 0  "tissue: non-cancerous colorectal"  ...  "pjunlab@hotmail.com"
# 1  "tissue: non-cancerous colorectal"  ...  "pjunlab@hotmail.com"
# 2  "tissue: non-cancerous colorectal"  ...  "pjunlab@hotmail.com"
# 3  "tissue: non-cancerous colorectal"  ...  "pjunlab@hotmail.com"
# 4  "tissue: non-cancerous colorectal"  ...  "pjunlab@hotmail.com"
#
#                   contact_department  \
# 0  "Academy of Integrative Medicine"
# 1  "Academy of Integrative Medicine"
# 2  "Academy of Integrative Medicine"
# 3  "Academy of Integrative Medicine"
# 4  "Academy of Integrative Medicine"
#
#                                    contact_institute  \
# 0  "Fujian University of Traditional Chinese Medi...
# 1  "Fujian University of Traditional Chinese Medi...
# 2  "Fujian University of Traditional Chinese Medi...
# 3  "Fujian University of Traditional Chinese Medi...
# 4  "Fujian University of Traditional Chinese Medi...
#
#                      contact_address contact_city contact_state  \
# 0  "1 Qiuyang Road, Minhou Shangjie"     "Fuzhou"      "Fujian"
# 1  "1 Qiuyang Road, Minhou Shangjie"     "Fuzhou"      "Fujian"
# 2  "1 Qiuyang Road, Minhou Shangjie"     "Fuzhou"      "Fujian"
# 3  "1 Qiuyang Road, Minhou Shangjie"     "Fuzhou"      "Fujian"
# 4  "1 Qiuyang Road, Minhou Shangjie"     "Fuzhou"      "Fujian"
#
#   contact_zip/postal_code contact_country  \
# 0                "350122"         "China"
# 1                "350122"         "China"
# 2                "350122"         "China"
# 3                "350122"         "China"
# 4                "350122"         "China"
#
#                                   supplementary_file data_row_count
# 0  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM310...        "49395"
# 1  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM310...        "49395"
# 2  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM310...        "49395"
# 3  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM310...        "49395"
# 4  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM310...        "49395"
#
# [5 rows x 32 columns]

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    28 non-null     object
#  1   geo_accession            28 non-null     object
#  2   status                   28 non-null     object
#  3   submission_date          28 non-null     object
#  4   last_update_date         28 non-null     object
#  5   type                     28 non-null     object
#  6   channel_count            28 non-null     object
#  7   source_name_ch1          28 non-null     object
#  8   organism_ch1             28 non-null     object
#  9   characteristics_ch1      28 non-null     object
#  10  treatment_protocol_ch1   28 non-null     object
#  11  molecule_ch1             28 non-null     object
#  12  extract_protocol_ch1     28 non-null     object
#  13  label_ch1                28 non-null     object
#  14  label_protocol_ch1       28 non-null     object
#  15  taxid_ch1                28 non-null     object
#  16  hyb_protocol             28 non-null     object
#  17  scan_protocol            28 non-null     object
#  18  description              28 non-null     object
#  19  data_processing          28 non-null     object
#  20  platform_id              28 non-null     object
#  21  contact_name             28 non-null     object
#  22  contact_email            28 non-null     object
#  23  contact_department       28 non-null     object
#  24  contact_institute        28 non-null     object
#  25  contact_address          28 non-null     object
#  26  contact_city             28 non-null     object
#  27  contact_state            28 non-null     object
#  28  contact_zip/postal_code  28 non-null     object
#  29  contact_country          28 non-null     object
#  30  supplementary_file       28 non-null     object
#  31  data_row_count           28 non-null     object
# dtypes: object(32)
# memory usage: 7.1+ KB

# %%
metadata.shape
# Out:
# (28, 32)

# %%
metadata.columns
# Out:
# Index(['title', 'geo_accession', 'status', 'submission_date',
#        'last_update_date', 'type', 'channel_count', 'source_name_ch1',
#        'organism_ch1', 'characteristics_ch1', 'treatment_protocol_ch1',
#        'molecule_ch1', 'extract_protocol_ch1', 'label_ch1',
#        'label_protocol_ch1', 'taxid_ch1', 'hyb_protocol', 'scan_protocol',
#        'description', 'data_processing', 'platform_id', 'contact_name',
#        'contact_email', 'contact_department', 'contact_institute',
#        'contact_address', 'contact_city', 'contact_state',
#        'contact_zip/postal_code', 'contact_country', 'supplementary_file',
#        'data_row_count'],
#       dtype='object')

# %%
# List of columns to remove
columns_to_remove = [
    "title","status", "submission_date", "last_update_date", "type", "channel_count",
      'source_name_ch1', 'organism_ch1', 'case_id',
       'treatment_protocol_ch1', 'growth_protocol_ch1', 'molecule_ch1',
       'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1', 'taxid_ch1',
       'hyb_protocol', 'scan_protocol', 'description', 'data_processing',
       'platform_id', 'contact_name', 'contact_email', 'contact_department',
       'contact_institute', 'contact_address', 'contact_city', 'contact_state',
       'contact_zip/postal_code', 'contact_country', 'supplementary_file',
       'data_row_count'
]

metadata_cleaned = metadata.drop(columns=columns_to_remove, errors="ignore")

# %%
metadata_cleaned.head()
# Out:
#   geo_accession                 characteristics_ch1
# 0  "GSM3108231"  "tissue: non-cancerous colorectal"
# 1  "GSM3108232"  "tissue: non-cancerous colorectal"
# 2  "GSM3108233"  "tissue: non-cancerous colorectal"
# 3  "GSM3108234"  "tissue: non-cancerous colorectal"
# 4  "GSM3108235"  "tissue: non-cancerous colorectal"

# %%
metadata_cleaned.tail()
# Out:
#    geo_accession             characteristics_ch1
# 23  "GSM3108254"  "tissue: colorectal carcinoma"
# 24  "GSM3108255"  "tissue: colorectal carcinoma"
# 25  "GSM3108256"  "tissue: colorectal carcinoma"
# 26  "GSM3108257"  "tissue: colorectal carcinoma"
# 27  "GSM3108258"  "tissue: colorectal carcinoma"

# %%
metadata_cleaned["target"] = metadata_cleaned["characteristics_ch1"].str.extract(r"(non-cancerous|colorectal carcinoma)")

# %%
metadata_cleaned.head()
# Out:
#   geo_accession                 characteristics_ch1         target
# 0  "GSM3108231"  "tissue: non-cancerous colorectal"  non-cancerous
# 1  "GSM3108232"  "tissue: non-cancerous colorectal"  non-cancerous
# 2  "GSM3108233"  "tissue: non-cancerous colorectal"  non-cancerous
# 3  "GSM3108234"  "tissue: non-cancerous colorectal"  non-cancerous
# 4  "GSM3108235"  "tissue: non-cancerous colorectal"  non-cancerous

# %%
metadata_cleaned.tail()
# Out:
#    geo_accession             characteristics_ch1                target
# 23  "GSM3108254"  "tissue: colorectal carcinoma"  colorectal carcinoma
# 24  "GSM3108255"  "tissue: colorectal carcinoma"  colorectal carcinoma
# 25  "GSM3108256"  "tissue: colorectal carcinoma"  colorectal carcinoma
# 26  "GSM3108257"  "tissue: colorectal carcinoma"  colorectal carcinoma
# 27  "GSM3108258"  "tissue: colorectal carcinoma"  colorectal carcinoma

# %%
metadata_cleaned
# Out:
#    geo_accession                 characteristics_ch1                target
# 0   "GSM3108231"  "tissue: non-cancerous colorectal"         non-cancerous
# 1   "GSM3108232"  "tissue: non-cancerous colorectal"         non-cancerous
# 2   "GSM3108233"  "tissue: non-cancerous colorectal"         non-cancerous
# 3   "GSM3108234"  "tissue: non-cancerous colorectal"         non-cancerous
# 4   "GSM3108235"  "tissue: non-cancerous colorectal"         non-cancerous
# 5   "GSM3108236"  "tissue: non-cancerous colorectal"         non-cancerous
# 6   "GSM3108237"  "tissue: non-cancerous colorectal"         non-cancerous
# 7   "GSM3108238"  "tissue: non-cancerous colorectal"         non-cancerous
# 8   "GSM3108239"  "tissue: non-cancerous colorectal"         non-cancerous
# 9   "GSM3108240"  "tissue: non-cancerous colorectal"         non-cancerous
# 10  "GSM3108241"  "tissue: non-cancerous colorectal"         non-cancerous
# 11  "GSM3108242"  "tissue: non-cancerous colorectal"         non-cancerous
# 12  "GSM3108243"  "tissue: non-cancerous colorectal"         non-cancerous
# 13  "GSM3108244"  "tissue: non-cancerous colorectal"         non-cancerous
# 14  "GSM3108245"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 15  "GSM3108246"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 16  "GSM3108247"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 17  "GSM3108248"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 18  "GSM3108249"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 19  "GSM3108250"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 20  "GSM3108251"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 21  "GSM3108252"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 22  "GSM3108253"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 23  "GSM3108254"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 24  "GSM3108255"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 25  "GSM3108256"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 26  "GSM3108257"      "tissue: colorectal carcinoma"  colorectal carcinoma
# 27  "GSM3108258"      "tissue: colorectal carcinoma"  colorectal carcinoma

# %%
metadata_final = metadata_cleaned.drop(columns='characteristics_ch1', errors="ignore")

# %%
metadata_final.head()
# Out:
#   geo_accession         target
# 0  "GSM3108231"  non-cancerous
# 1  "GSM3108232"  non-cancerous
# 2  "GSM3108233"  non-cancerous
# 3  "GSM3108234"  non-cancerous
# 4  "GSM3108235"  non-cancerous

# %%
# Remove quotes from the geo_accession column (it's the first column)
metadata_final.iloc[:, 0] = metadata_final.iloc[:, 0].str.replace('"', '', regex=False)

# %%
metadata_cleaned= metadata_final
metadata_cleaned.head()
# Out:
#   geo_accession         target
# 0    GSM3108231  non-cancerous
# 1    GSM3108232  non-cancerous
# 2    GSM3108233  non-cancerous
# 3    GSM3108234  non-cancerous
# 4    GSM3108235  non-cancerous

# %%
# Save the cleaned metadata
metadata_cleaned.to_csv("metadata_cleaned.csv", index=False)

print("Columns removed and saved as metadata_cleaned.csv")
# Out:
# Columns removed and saved as metadata_cleaned.csv
