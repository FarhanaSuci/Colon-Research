# %%
import pandas as pd

# %%
#read all metadata
metadata_file = "GSE41328_metadata_all.csv" 
metadata = pd.read_csv(metadata_file)

# %%
metadata.describe()
# Out:
#                                                     title geo_accession  \
# count                                                  20            20
# unique                                                 20            20
# top     "AFX platform, lab 1, matched normal colon tis...  "GSM1014798"
# freq                                                    1             1
#
#                          status submission_date last_update_date   type  \
# count                        20              20               20     20
# unique                        1               1                1      1
# top     "Public on Oct 03 2012"   "Oct 03 2012"    "Oct 03 2012"  "RNA"
# freq                         20              20               20     20
#
#        channel_count                                    source_name_ch1  \
# count             20                                                 20
# unique             1                                                  2
# top              "1"  "Sample type N (Normal, matched normal colon t...
# freq              20                                                 10
#
#           organism_ch1 characteristics_ch1  ...           contact_email  \
# count               20                  20  ...                      20
# unique               1                   2  ...                       1
# top     "Homo sapiens"            "lab: 1"  ...  "cchen63@illinois.edu"
# freq                20                  10  ...                      20
#
#        contact_department         contact_institute  \
# count                  20                        20
# unique                  1                         1
# top      "Bioengineering"  "University of illinois"
# freq                   20                        20
#
#                   contact_address contact_city contact_state  \
# count                          20           20            20
# unique                          1            1             1
# top     "1206 West Gregory Drive"     "Urbana"    "Illinois"
# freq                           20           20            20
#
#        contact_zip/postal_code contact_country  \
# count                       20              20
# unique                       1               1
# top                    "61801"           "USA"
# freq                        20              20
#
#                                        supplementary_file data_row_count
# count                                                  20             20
# unique                                                 20              1
# top     "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM101...        "54675"
# freq                                                    1             20
#
# [4 rows x 31 columns]

# %%
metadata.head()
# Out:
#                                                title geo_accession  \
# 0  "AFX platform, lab 1, matched normal colon tis...  "GSM1014798"
# 1  "AFX platform, lab 1, matched normal colon tis...  "GSM1014799"
# 2  "AFX platform, lab 1, matched normal colon tis...  "GSM1014800"
# 3  "AFX platform, lab 1, matched normal colon tis...  "GSM1014801"
# 4  "AFX platform, lab 1, matched normal colon tis...  "GSM1014802"
#
#                     status submission_date last_update_date   type  \
# 0  "Public on Oct 03 2012"   "Oct 03 2012"    "Oct 03 2012"  "RNA"
# 1  "Public on Oct 03 2012"   "Oct 03 2012"    "Oct 03 2012"  "RNA"
# 2  "Public on Oct 03 2012"   "Oct 03 2012"    "Oct 03 2012"  "RNA"
# 3  "Public on Oct 03 2012"   "Oct 03 2012"    "Oct 03 2012"  "RNA"
# 4  "Public on Oct 03 2012"   "Oct 03 2012"    "Oct 03 2012"  "RNA"
#
#   channel_count                                    source_name_ch1  \
# 0           "1"  "Sample type N (Normal, matched normal colon t...
# 1           "1"  "Sample type N (Normal, matched normal colon t...
# 2           "1"  "Sample type N (Normal, matched normal colon t...
# 3           "1"  "Sample type N (Normal, matched normal colon t...
# 4           "1"  "Sample type N (Normal, matched normal colon t...
#
#      organism_ch1 characteristics_ch1  ...           contact_email  \
# 0  "Homo sapiens"            "lab: 1"  ...  "cchen63@illinois.edu"
# 1  "Homo sapiens"            "lab: 1"  ...  "cchen63@illinois.edu"
# 2  "Homo sapiens"            "lab: 1"  ...  "cchen63@illinois.edu"
# 3  "Homo sapiens"            "lab: 1"  ...  "cchen63@illinois.edu"
# 4  "Homo sapiens"            "lab: 1"  ...  "cchen63@illinois.edu"
#
#   contact_department         contact_institute            contact_address  \
# 0   "Bioengineering"  "University of illinois"  "1206 West Gregory Drive"
# 1   "Bioengineering"  "University of illinois"  "1206 West Gregory Drive"
# 2   "Bioengineering"  "University of illinois"  "1206 West Gregory Drive"
# 3   "Bioengineering"  "University of illinois"  "1206 West Gregory Drive"
# 4   "Bioengineering"  "University of illinois"  "1206 West Gregory Drive"
#
#   contact_city contact_state contact_zip/postal_code contact_country  \
# 0     "Urbana"    "Illinois"                 "61801"           "USA"
# 1     "Urbana"    "Illinois"                 "61801"           "USA"
# 2     "Urbana"    "Illinois"                 "61801"           "USA"
# 3     "Urbana"    "Illinois"                 "61801"           "USA"
# 4     "Urbana"    "Illinois"                 "61801"           "USA"
#
#                                   supplementary_file data_row_count
# 0  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM101...        "54675"
# 1  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM101...        "54675"
# 2  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM101...        "54675"
# 3  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM101...        "54675"
# 4  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM101...        "54675"
#
# [5 rows x 31 columns]

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    20 non-null     object
#  1   geo_accession            20 non-null     object
#  2   status                   20 non-null     object
#  3   submission_date          20 non-null     object
#  4   last_update_date         20 non-null     object
#  5   type                     20 non-null     object
#  6   channel_count            20 non-null     object
#  7   source_name_ch1          20 non-null     object
#  8   organism_ch1             20 non-null     object
#  9   characteristics_ch1      20 non-null     object
#  10  molecule_ch1             20 non-null     object
#  11  extract_protocol_ch1     20 non-null     object
#  12  label_ch1                20 non-null     object
#  13  label_protocol_ch1       20 non-null     object
#  14  taxid_ch1                20 non-null     object
#  15  hyb_protocol             20 non-null     object
#  16  scan_protocol            20 non-null     object
#  17  description              20 non-null     object
#  18  data_processing          20 non-null     object
#  19  platform_id              20 non-null     object
#  20  contact_name             20 non-null     object
#  21  contact_email            20 non-null     object
#  22  contact_department       20 non-null     object
#  23  contact_institute        20 non-null     object
#  24  contact_address          20 non-null     object
#  25  contact_city             20 non-null     object
#  26  contact_state            20 non-null     object
#  27  contact_zip/postal_code  20 non-null     object
#  28  contact_country          20 non-null     object
#  29  supplementary_file       20 non-null     object
#  30  data_row_count           20 non-null     object
# dtypes: object(31)
# memory usage: 5.0+ KB

# %%
metadata.shape
# Out:
# (20, 31)

# %%
metadata.columns
# Out:
# Index(['title', 'geo_accession', 'status', 'submission_date',
#        'last_update_date', 'type', 'channel_count', 'source_name_ch1',
#        'organism_ch1', 'characteristics_ch1', 'molecule_ch1',
#        'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1', 'taxid_ch1',
#        'hyb_protocol', 'scan_protocol', 'description', 'data_processing',
#        'platform_id', 'contact_name', 'contact_email', 'contact_department',
#        'contact_institute', 'contact_address', 'contact_city', 'contact_state',
#        'contact_zip/postal_code', 'contact_country', 'supplementary_file',
#        'data_row_count'],
#       dtype='object')

# %%
# List of columns to remove
columns_to_remove = [
    "status", "submission_date", "last_update_date", "type", "channel_count",
    "source_name_ch1", "organism_ch1", "characteristics_ch1",'molecule_ch1',
       'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1', 'taxid_ch1',
       'hyb_protocol', 'scan_protocol', 'description', 'data_processing', "platform_id",
    "contact_name", "contact_email",'contact_phone', "contact_institute", "contact_address",
    "contact_city", 'contact_state', "contact_zip/postal_code", "contact_country","contact_department",
    "supplementary_file", "data_row_count"
]

metadata_cleaned = metadata.drop(columns=columns_to_remove, errors="ignore")

# %%
metadata_cleaned.head()
# Out:
#                                                title geo_accession
# 0  "AFX platform, lab 1, matched normal colon tis...  "GSM1014798"
# 1  "AFX platform, lab 1, matched normal colon tis...  "GSM1014799"
# 2  "AFX platform, lab 1, matched normal colon tis...  "GSM1014800"
# 3  "AFX platform, lab 1, matched normal colon tis...  "GSM1014801"
# 4  "AFX platform, lab 1, matched normal colon tis...  "GSM1014802"

# %%
metadata_cleaned.tail()
# Out:
#                                                 title geo_accession
# 15  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014813"
# 16  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014814"
# 17  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014815"
# 18  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014816"
# 19  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014817"

# %%
metadata_cleaned["target"] = metadata_cleaned["title"].str.extract(r"(normal|tumor)")

# %%
metadata_cleaned.head()
# Out:
#                                                title geo_accession  target
# 0  "AFX platform, lab 1, matched normal colon tis...  "GSM1014798"  normal
# 1  "AFX platform, lab 1, matched normal colon tis...  "GSM1014799"  normal
# 2  "AFX platform, lab 1, matched normal colon tis...  "GSM1014800"  normal
# 3  "AFX platform, lab 1, matched normal colon tis...  "GSM1014801"  normal
# 4  "AFX platform, lab 1, matched normal colon tis...  "GSM1014802"  normal

# %%
metadata_cleaned.tail()
# Out:
#                                                 title geo_accession target
# 15  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014813"  tumor
# 16  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014814"  tumor
# 17  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014815"  tumor
# 18  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014816"  tumor
# 19  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014817"  tumor

# %%
metadata_cleaned
# Out:
#                                                 title geo_accession  target
# 0   "AFX platform, lab 1, matched normal colon tis...  "GSM1014798"  normal
# 1   "AFX platform, lab 1, matched normal colon tis...  "GSM1014799"  normal
# 2   "AFX platform, lab 1, matched normal colon tis...  "GSM1014800"  normal
# 3   "AFX platform, lab 1, matched normal colon tis...  "GSM1014801"  normal
# 4   "AFX platform, lab 1, matched normal colon tis...  "GSM1014802"  normal
# 5   "AFX platform, lab 1, tumor, colon adenocarcin...  "GSM1014803"   tumor
# 6   "AFX platform, lab 1, tumor, colon adenocarcin...  "GSM1014804"   tumor
# 7   "AFX platform, lab 1, tumor, colon adenocarcin...  "GSM1014805"   tumor
# 8   "AFX platform, lab 1, tumor, colon adenocarcin...  "GSM1014806"   tumor
# 9   "AFX platform, lab 1, tumor, colon adenocarcin...  "GSM1014807"   tumor
# 10  "AFX platform, lab 2, matched normal colon tis...  "GSM1014808"  normal
# 11  "AFX platform, lab 2, matched normal colon tis...  "GSM1014809"  normal
# 12  "AFX platform, lab 2, matched normal colon tis...  "GSM1014810"  normal
# 13  "AFX platform, lab 2, matched normal colon tis...  "GSM1014811"  normal
# 14  "AFX platform, lab 2, matched normal colon tis...  "GSM1014812"  normal
# 15  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014813"   tumor
# 16  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014814"   tumor
# 17  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014815"   tumor
# 18  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014816"   tumor
# 19  "AFX platform, lab 2, tumor, colon adenocarcin...  "GSM1014817"   tumor

# %%
metadata_final = metadata_cleaned.drop(columns='title', errors="ignore")

# %%
metadata_final.head()
# Out:
#   geo_accession  target
# 0  "GSM1014798"  normal
# 1  "GSM1014799"  normal
# 2  "GSM1014800"  normal
# 3  "GSM1014801"  normal
# 4  "GSM1014802"  normal

# %%
# Remove quotes from the geo_accession column (it's the first column)
metadata_final.iloc[:, 0] = metadata_final.iloc[:, 0].str.replace('"', '', regex=False)

# %%
metadata_cleaned= metadata_final
metadata_cleaned.head()
# Out:
#   geo_accession  target
# 0    GSM1014798  normal
# 1    GSM1014799  normal
# 2    GSM1014800  normal
# 3    GSM1014801  normal
# 4    GSM1014802  normal

# %%
# Save the cleaned metadata
metadata_cleaned.to_csv("metadata_cleaned.csv", index=False)

print("Columns removed and saved as metadata_cleaned.csv")
# Out:
# Columns removed and saved as metadata_cleaned.csv
