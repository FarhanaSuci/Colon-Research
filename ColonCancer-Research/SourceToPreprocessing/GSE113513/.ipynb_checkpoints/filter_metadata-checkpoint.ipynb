# %%
import pandas as pd

# %%
metadata_file = "metadata_cleaned.csv"
metadata = pd.read_csv(metadata_file)

# %%
metadata
# Out:
#    geo_accession                target
# 0     GSM3108231         non-cancerous
# 1     GSM3108232         non-cancerous
# 2     GSM3108233         non-cancerous
# 3     GSM3108234         non-cancerous
# 4     GSM3108235         non-cancerous
# 5     GSM3108236         non-cancerous
# 6     GSM3108237         non-cancerous
# 7     GSM3108238         non-cancerous
# 8     GSM3108239         non-cancerous
# 9     GSM3108240         non-cancerous
# 10    GSM3108241         non-cancerous
# 11    GSM3108242         non-cancerous
# 12    GSM3108243         non-cancerous
# 13    GSM3108244         non-cancerous
# 14    GSM3108245  colorectal carcinoma
# 15    GSM3108246  colorectal carcinoma
# 16    GSM3108247  colorectal carcinoma
# 17    GSM3108248  colorectal carcinoma
# 18    GSM3108249  colorectal carcinoma
# 19    GSM3108250  colorectal carcinoma
# 20    GSM3108251  colorectal carcinoma
# 21    GSM3108252  colorectal carcinoma
# 22    GSM3108253  colorectal carcinoma
# 23    GSM3108254  colorectal carcinoma
# 24    GSM3108255  colorectal carcinoma
# 25    GSM3108256  colorectal carcinoma
# 26    GSM3108257  colorectal carcinoma
# 27    GSM3108258  colorectal carcinoma

# %%
class_counts = metadata["target"].value_counts()
print(class_counts)
# Out:
# target
# non-cancerous           14
# colorectal carcinoma    14
# Name: count, dtype: int64

# %%
metadata['target'].replace(['non-cancerous', 'colorectal carcinoma'],
                        [0, 1], inplace=True)

# %%
metadata
# Out:
#    geo_accession  target
# 0     GSM3108231       0
# 1     GSM3108232       0
# 2     GSM3108233       0
# 3     GSM3108234       0
# 4     GSM3108235       0
# 5     GSM3108236       0
# 6     GSM3108237       0
# 7     GSM3108238       0
# 8     GSM3108239       0
# 9     GSM3108240       0
# 10    GSM3108241       0
# 11    GSM3108242       0
# 12    GSM3108243       0
# 13    GSM3108244       0
# 14    GSM3108245       1
# 15    GSM3108246       1
# 16    GSM3108247       1
# 17    GSM3108248       1
# 18    GSM3108249       1
# 19    GSM3108250       1
# 20    GSM3108251       1
# 21    GSM3108252       1
# 22    GSM3108253       1
# 23    GSM3108254       1
# 24    GSM3108255       1
# 25    GSM3108256       1
# 26    GSM3108257       1
# 27    GSM3108258       1

# %%
class_counts = metadata["target"].value_counts()
print(class_counts)
# Out:
# target
# 0    14
# 1    14
# Name: count, dtype: int64

# %%
# Save the cleaned metadata to a new CSV file
output_file = "GSE113513_target_metadata.csv"
metadata.to_csv(output_file, index=False)

print(f"Cleaned metadata saved to {output_file}")
# Out:
# Cleaned metadata saved to GSE113513_target_metadata.csv
