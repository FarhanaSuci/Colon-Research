# %%
import pandas as pd

# %%
metadata_file = "metadata_cleaned.csv"
metadata = pd.read_csv(metadata_file)

# %%
metadata
# Out:
#     geo_accession    target
# 0      GSM1092909  nontumor
# 1      GSM1092910     Tumor
# 2      GSM1092911  nontumor
# 3      GSM1092912     Tumor
# 4      GSM1092913  nontumor
# ..            ...       ...
# 106    GSM1093015     Tumor
# 107    GSM1093016  nontumor
# 108    GSM1093017     Tumor
# 109    GSM1093018  nontumor
# 110    GSM1093019     Tumor
#
# [111 rows x 2 columns]

# %%
class_counts = metadata["target"].value_counts()
print(class_counts)
# Out:
# target
# Tumor       56
# nontumor    55
# Name: count, dtype: int64

# %%
metadata['target'].replace(['nontumor', 'Tumor'],
                        [0, 1], inplace=True)

# %%
metadata
# Out:
#     geo_accession  target
# 0      GSM1092909       0
# 1      GSM1092910       1
# 2      GSM1092911       0
# 3      GSM1092912       1
# 4      GSM1092913       0
# ..            ...     ...
# 106    GSM1093015       1
# 107    GSM1093016       0
# 108    GSM1093017       1
# 109    GSM1093018       0
# 110    GSM1093019       1
#
# [111 rows x 2 columns]

# %%
class_counts = metadata["target"].value_counts()
print(class_counts)
# Out:
# target
# 1    56
# 0    55
# Name: count, dtype: int64

# %%
# Save the cleaned metadata to a new CSV file
output_file = "GSE44861_target_metadata.csv"
metadata.to_csv(output_file, index=False)

print(f"Cleaned metadata saved to {output_file}")
# Out:
# Cleaned metadata saved to GSE44861_target_metadata.csv
