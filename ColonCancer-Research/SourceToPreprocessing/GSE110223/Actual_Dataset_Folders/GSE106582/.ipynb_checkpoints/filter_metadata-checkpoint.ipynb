# %%
import pandas as pd

# %%
metadata_file = "metadata_cleaned.csv"
metadata = pd.read_csv(metadata_file)

# %%
metadata
# Out:
#     geo_accession  target
# 0      GSM2843099   tumor
# 1      GSM2843100  mucosa
# 2      GSM2843101   tumor
# 3      GSM2843102  mucosa
# 4      GSM2843103  mucosa
# ..            ...     ...
# 189    GSM2843288   tumor
# 190    GSM2843289  mucosa
# 191    GSM2843290  mucosa
# 192    GSM2843291   tumor
# 193    GSM2843292  mucosa
#
# [194 rows x 2 columns]

# %%
class_counts = metadata["target"].value_counts()
print(class_counts)
# Out:
# target
# mucosa    117
# tumor      77
# Name: count, dtype: int64

# %%
metadata['target'].replace(['mucosa', 'tumor'],
                        [0, 1], inplace=True)

# %%
metadata
# Out:
#     geo_accession  target
# 0      GSM2843099       1
# 1      GSM2843100       0
# 2      GSM2843101       1
# 3      GSM2843102       0
# 4      GSM2843103       0
# ..            ...     ...
# 189    GSM2843288       1
# 190    GSM2843289       0
# 191    GSM2843290       0
# 192    GSM2843291       1
# 193    GSM2843292       0
#
# [194 rows x 2 columns]

# %%
# Save the cleaned metadata to a new CSV file
output_file = "GSE106582_target_metadata.csv"
metadata.to_csv(output_file, index=False)

print(f"Cleaned metadata saved to {output_file}")
# Out:
# Cleaned metadata saved to GSE106582_target_metadata.csv
