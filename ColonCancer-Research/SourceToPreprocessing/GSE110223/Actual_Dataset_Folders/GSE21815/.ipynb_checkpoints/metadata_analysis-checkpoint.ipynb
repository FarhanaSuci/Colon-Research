# %%
import pandas as pd

# %%
#read all metadata
metadata_file = "GSE21815_metadata_all.csv" 
metadata = pd.read_csv(metadata_file)

# %%
metadata.describe()
# Out:
#           title geo_accession                   status submission_date  \
# count       141           141                      141             141
# unique      141           141                        1               1
# top     "CRC-1"   "GSM543123"  "Public on Sep 01 2011"   "May 13 2010"
# freq          1             1                      141             141
#
#        last_update_date   type channel_count      source_name_ch1  \
# count               141    141           141                  141
# unique                2      1             1                    2
# top       "Jan 23 2012"  "RNA"           "1"  "colorectal cancer"
# freq                 71    141           141                  132
#
#           organism_ch1 characteristics_ch1  ...  \
# count              141                 141  ...
# unique               1                   9  ...
# top     "Homo sapiens"                  ""  ...
# freq               141                  70  ...
#
#                         contact_laboratory       contact_department  \
# count                                  141                      141
# unique                                   1                        1
# top     "Kyushu Univeristy Beppu Hospital"  "Department of Surgery"
# freq                                   141                      141
#
#           contact_institute     contact_address contact_city contact_state  \
# count                   141                 141          141           141
# unique                    1                   1            1             1
# top     "Kyushu university"  "4546 Tsurumihara"      "Beppu"        "Oita"
# freq                    141                 141          141           141
#
#        contact_zip/postal_code contact_country  \
# count                      141             141
# unique                       1               1
# top                 "874-0838"         "Japan"
# freq                       141             141
#
#                                        supplementary_file data_row_count
# count                                                 141            141
# unique                                                141              1
# top     "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM543...        "41000"
# freq                                                    1            141
#
# [4 rows x 35 columns]

# %%
metadata.head()
# Out:
#      title geo_accession                   status submission_date  \
# 0  "CRC-1"   "GSM543123"  "Public on Sep 01 2011"   "May 13 2010"
# 1  "CRC-2"   "GSM543124"  "Public on Sep 01 2011"   "May 13 2010"
# 2  "CRC-3"   "GSM543125"  "Public on Sep 01 2011"   "May 13 2010"
# 3  "CRC-4"   "GSM543126"  "Public on Sep 01 2011"   "May 13 2010"
# 4  "CRC-5"   "GSM543127"  "Public on Sep 01 2011"   "May 13 2010"
#
#   last_update_date   type channel_count      source_name_ch1    organism_ch1  \
# 0    "Jan 23 2012"  "RNA"           "1"  "colorectal cancer"  "Homo sapiens"
# 1    "Jan 23 2012"  "RNA"           "1"  "colorectal cancer"  "Homo sapiens"
# 2    "Sep 01 2011"  "RNA"           "1"  "colorectal cancer"  "Homo sapiens"
# 3    "Jan 23 2012"  "RNA"           "1"  "colorectal cancer"  "Homo sapiens"
# 4    "Sep 01 2011"  "RNA"           "1"  "colorectal cancer"  "Homo sapiens"
#
#   characteristics_ch1  ...                  contact_laboratory  \
# 0        "depth: pSE"  ...  "Kyushu Univeristy Beppu Hospital"
# 1        "depth: pSS"  ...  "Kyushu Univeristy Beppu Hospital"
# 2                  ""  ...  "Kyushu Univeristy Beppu Hospital"
# 3        "depth: pSM"  ...  "Kyushu Univeristy Beppu Hospital"
# 4                  ""  ...  "Kyushu Univeristy Beppu Hospital"
#
#         contact_department    contact_institute     contact_address  \
# 0  "Department of Surgery"  "Kyushu university"  "4546 Tsurumihara"
# 1  "Department of Surgery"  "Kyushu university"  "4546 Tsurumihara"
# 2  "Department of Surgery"  "Kyushu university"  "4546 Tsurumihara"
# 3  "Department of Surgery"  "Kyushu university"  "4546 Tsurumihara"
# 4  "Department of Surgery"  "Kyushu university"  "4546 Tsurumihara"
#
#   contact_city contact_state contact_zip/postal_code contact_country  \
# 0      "Beppu"        "Oita"              "874-0838"         "Japan"
# 1      "Beppu"        "Oita"              "874-0838"         "Japan"
# 2      "Beppu"        "Oita"              "874-0838"         "Japan"
# 3      "Beppu"        "Oita"              "874-0838"         "Japan"
# 4      "Beppu"        "Oita"              "874-0838"         "Japan"
#
#                                   supplementary_file data_row_count
# 0  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM543...        "41000"
# 1  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM543...        "41000"
# 2  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM543...        "41000"
# 3  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM543...        "41000"
# 4  "ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM543...        "41000"
#
# [5 rows x 35 columns]

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    141 non-null    object
#  1   geo_accession            141 non-null    object
#  2   status                   141 non-null    object
#  3   submission_date          141 non-null    object
#  4   last_update_date         141 non-null    object
#  5   type                     141 non-null    object
#  6   channel_count            141 non-null    object
#  7   source_name_ch1          141 non-null    object
#  8   organism_ch1             141 non-null    object
#  9   characteristics_ch1      141 non-null    object
#  10  treatment_protocol_ch1   141 non-null    object
#  11  molecule_ch1             141 non-null    object
#  12  extract_protocol_ch1     141 non-null    object
#  13  label_ch1                141 non-null    object
#  14  label_protocol_ch1       141 non-null    object
#  15  taxid_ch1                141 non-null    object
#  16  hyb_protocol             141 non-null    object
#  17  scan_protocol            141 non-null    object
#  18  description              141 non-null    object
#  19  data_processing          141 non-null    object
#  20  platform_id              141 non-null    object
#  21  contact_name             141 non-null    object
#  22  contact_email            141 non-null    object
#  23  contact_phone            141 non-null    object
#  24  contact_fax              141 non-null    object
#  25  contact_laboratory       141 non-null    object
#  26  contact_department       141 non-null    object
#  27  contact_institute        141 non-null    object
#  28  contact_address          141 non-null    object
#  29  contact_city             141 non-null    object
#  30  contact_state            141 non-null    object
#  31  contact_zip/postal_code  141 non-null    object
#  32  contact_country          141 non-null    object
#  33  supplementary_file       141 non-null    object
#  34  data_row_count           141 non-null    object
# dtypes: object(35)
# memory usage: 38.7+ KB

# %%
metadata.shape
# Out:
# (141, 35)

# %%
metadata.columns
# Out:
# Index(['title', 'geo_accession', 'status', 'submission_date',
#        'last_update_date', 'type', 'channel_count', 'source_name_ch1',
#        'organism_ch1', 'characteristics_ch1', 'treatment_protocol_ch1',
#        'molecule_ch1', 'extract_protocol_ch1', 'label_ch1',
#        'label_protocol_ch1', 'taxid_ch1', 'hyb_protocol', 'scan_protocol',
#        'description', 'data_processing', 'platform_id', 'contact_name',
#        'contact_email', 'contact_phone', 'contact_fax', 'contact_laboratory',
#        'contact_department', 'contact_institute', 'contact_address',
#        'contact_city', 'contact_state', 'contact_zip/postal_code',
#        'contact_country', 'supplementary_file', 'data_row_count'],
#       dtype='object')

# %%
# List of columns to remove
columns_to_remove = [
    "title","status", "submission_date", "last_update_date", "type", "channel_count",
     "organism_ch1", "characteristics_ch1",'molecule_ch1',
       'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1',"treatment_protocol_ch1", 'taxid_ch1',
       'hyb_protocol', 'scan_protocol', 'description', 'data_processing', "platform_id",
    "contact_name", "contact_email",'contact_phone', "contact_institute", "contact_address",
    "contact_city", 'contact_state', "contact_zip/postal_code", "contact_country","contact_department",
    "contact_fax","contact_laboratory", "supplementary_file", "data_row_count"
]

metadata_cleaned = metadata.drop(columns=columns_to_remove, errors="ignore")

# %%
metadata_cleaned.head()
# Out:
#   geo_accession      source_name_ch1
# 0   "GSM543123"  "colorectal cancer"
# 1   "GSM543124"  "colorectal cancer"
# 2   "GSM543125"  "colorectal cancer"
# 3   "GSM543126"  "colorectal cancer"
# 4   "GSM543127"  "colorectal cancer"

# %%
metadata_cleaned.tail()
# Out:
#     geo_accession      source_name_ch1
# 136   "GSM543259"  "normal epithelium"
# 137   "GSM543260"  "normal epithelium"
# 138   "GSM543261"  "normal epithelium"
# 139   "GSM543262"  "normal epithelium"
# 140   "GSM543263"  "normal epithelium"

# %%
metadata_cleaned["target"] = metadata_cleaned["source_name_ch1"].str.extract(r"(normal|cancer)")

# %%
metadata_cleaned.head()
# Out:
#   geo_accession      source_name_ch1  target
# 0   "GSM543123"  "colorectal cancer"  cancer
# 1   "GSM543124"  "colorectal cancer"  cancer
# 2   "GSM543125"  "colorectal cancer"  cancer
# 3   "GSM543126"  "colorectal cancer"  cancer
# 4   "GSM543127"  "colorectal cancer"  cancer

# %%
metadata_cleaned.tail()
# Out:
#     geo_accession      source_name_ch1  target
# 136   "GSM543259"  "normal epithelium"  normal
# 137   "GSM543260"  "normal epithelium"  normal
# 138   "GSM543261"  "normal epithelium"  normal
# 139   "GSM543262"  "normal epithelium"  normal
# 140   "GSM543263"  "normal epithelium"  normal

# %%
metadata_cleaned
# Out:
#     geo_accession      source_name_ch1  target
# 0     "GSM543123"  "colorectal cancer"  cancer
# 1     "GSM543124"  "colorectal cancer"  cancer
# 2     "GSM543125"  "colorectal cancer"  cancer
# 3     "GSM543126"  "colorectal cancer"  cancer
# 4     "GSM543127"  "colorectal cancer"  cancer
# ..            ...                  ...     ...
# 136   "GSM543259"  "normal epithelium"  normal
# 137   "GSM543260"  "normal epithelium"  normal
# 138   "GSM543261"  "normal epithelium"  normal
# 139   "GSM543262"  "normal epithelium"  normal
# 140   "GSM543263"  "normal epithelium"  normal
#
# [141 rows x 3 columns]

# %%
metadata_final = metadata_cleaned.drop(columns='source_name_ch1', errors="ignore")

# %%
metadata_final.head()
# Out:
#   geo_accession  target
# 0   "GSM543123"  cancer
# 1   "GSM543124"  cancer
# 2   "GSM543125"  cancer
# 3   "GSM543126"  cancer
# 4   "GSM543127"  cancer

# %%
# Remove quotes from the geo_accession column (it's the first column)
metadata_final.iloc[:, 0] = metadata_final.iloc[:, 0].str.replace('"', '', regex=False)

# %%
metadata_cleaned= metadata_final
metadata_cleaned.head()
# Out:
#   geo_accession  target
# 0     GSM543123  cancer
# 1     GSM543124  cancer
# 2     GSM543125  cancer
# 3     GSM543126  cancer
# 4     GSM543127  cancer

# %%
# Save the cleaned metadata
metadata_cleaned.to_csv("metadata_cleaned.csv", index=False)

print("Columns removed and saved as metadata_cleaned.csv")
# Out:
# Columns removed and saved as metadata_cleaned.csv
